# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.74-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: lxml>=4.5.1 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from yfinance) (4.9.1)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 3.5 MB/s
# Requirement already satisfied: numpy>=1.15 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from yfinance) (1.23.2)
# Requirement already satisfied: pandas>=0.24.0 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from yfinance) (1.4.3)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.6.15-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 43.2 MB/s
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 11.6 MB/s
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 50.8 MB/s
# Requirement already satisfied: six>=1.5 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, multitasking, yfinance
# Successfully installed certifi-2022.6.15 charset-normalizer-2.1.1 idna-3.3 multitasking-0.0.11 requests-2.28.1 urllib3-1.26.12 yfinance-0.1.74
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/federicomoreno/PycharmProjects/UCEMA/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp38-cp38-macosx_10_9_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 9.5 MB/s                         | 1.6 MB 9.5 MB/s eta 0:00:01███████████▌                 | 3.3 MB 9.5 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-macosx_10_9_x86_64.whl (65 kB)
#      |████████████████████████████████| 65 kB 8.5 MB/s
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from matplotlib) (1.23.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp38-cp38-macosx_10_10_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 39.1 MB/s
# Requirement already satisfied: python-dateutil>=2.7 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.1-py3-none-any.whl (957 kB)
#      |████████████████████████████████| 957 kB 25.8 MB/s
# Requirement already satisfied: packaging>=20.0 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/federicomoreno/PycharmProjects/UCEMA/venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.37.1 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.2.0
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/federicomoreno/PycharmProjects/UCEMA/venv/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format


# berkshire hathaway inc. (b stock)


ypf_finance = yf.Ticker('ypf')
hist_preestatizacion = ypf_finance.history(start='2000-01-01', end='2022-08-24', auto_adjust=True)

# %%
hist_preestatizacion.reset_index(inplace=True)
hist_preestatizacion['Year'] = hist_preestatizacion['Date'].dt.year
hist_preestatizacion['Month'] = hist_preestatizacion['Date'].dt.month
hist_preestatizacion = hist_preestatizacion.reindex(columns=['Year','Month','Date','Open','High','Low','Close', 'Volume','Dividends']) #Saque "Stock Splits", todos los valores = 0"
hist_preestatizacion
# Out:
#       Year  Month       Date  Open  High   Low  Close   Volume  Dividends
# 0     2000      1 2000-01-03 11.65 11.65 11.49  11.53    52400       0.00
# 1     2000      1 2000-01-04 11.47 11.47 11.43  11.45    18300       0.00
# 2     2000      1 2000-01-05 11.37 11.59 11.31  11.51    42000       0.00
# 3     2000      1 2000-01-06 11.47 11.47 11.35  11.43     6400       0.00
# 4     2000      1 2000-01-07 11.39 11.67 11.37  11.55     8800       0.00
# ...    ...    ...        ...   ...   ...   ...    ...      ...        ...
# 5692  2022      8 2022-08-17  4.61  4.72  4.50   4.64  2434100       0.00
# 5693  2022      8 2022-08-18  4.65  4.94  4.65   4.85  2554100       0.00
# 5694  2022      8 2022-08-19  4.79  4.79  4.61   4.65  1594200       0.00
# 5695  2022      8 2022-08-22  4.59  4.86  4.47   4.77  2282600       0.00
# 5696  2022      8 2022-08-23  4.84  5.21  4.81   5.17  5211000       0.00
#
# [5697 rows x 9 columns]

# %%
hist_preestatizacion = hist_preestatizacion.groupby(['Year','Month']).agg({'Close': max})
hist_preestatizacion.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Year,Month'>
