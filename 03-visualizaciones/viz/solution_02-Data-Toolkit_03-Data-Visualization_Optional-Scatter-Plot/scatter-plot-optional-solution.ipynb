# %%
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('data/blobs.csv')
data.head()
# Out:
#    Unnamed: 0          A          B  Category
# 0           0  11.391521  15.500657         0
# 1           1  12.291186  11.814287         1
# 2           2  11.131218  14.681950         0
# 3           3  11.632530  14.896019         0
# 4           4  12.442849  15.156339         0

# %%
sns.scatterplot(data=data, x='A', y='B', alpha=.05, s=25, markers='o')

# %%
sns.scatterplot(data=data, x='B', y='A', hue='Category')

# %%
g = sns.FacetGrid(data=data, col='Category', hue='Category')
g.map(sns.scatterplot, "A", "B")

# %%
sns.relplot(data=data, x='A', y='B', hue='Category', col='Category')
