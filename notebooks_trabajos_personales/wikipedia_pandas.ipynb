# %%
import pandas as pd
df = pd.read_html("https://en.wikipedia.org/wiki/Roger_Federer")

# %%
df
# Out:
# [                                                    0  \
#  0         Federer at the 2016 Wimbledon Championships
#  1                                    Country (sports)
#  2                                           Residence
#  3                                                Born
#  4                                              Height
#  5                                          Turned pro
#  6                                             Retired
#  7                                               Plays
#  8                                               Coach
#  9                                         Prize money
#  10                                   Official website
#  11                                            Singles
#  12                                      Career record
#  13                                      Career titles
#  14                                    Highest ranking
#  15                         Grand Slam singles results
# ...

# %%
performances_ingcs= df[3]
performances_ingcs
# Out:
#         Tournament 1999 2000  2001 2002  2003  2004  2005  2006  2007  ...  \
# 0  Australian Open   Q1   3R    3R   4R    4R     W    SF     W     W  ...
# 1      French Open   1R   4R    QF   1R    1R    3R    SF     F     F  ...
# 2        Wimbledon   1R   1R    QF   1R     W     W     W     W  W[A]  ...
# 3          US Open   Q2   3R    4R   4R    4R  W[A]     W     W     W  ...
# 4         Win–loss  0–2  7–4  13–4  6–4  13–3  22–1  24–2  27–1  26–1  ...
#
#    2015  2016  2017  2018  2019 2020   2021       SR     W–L Win %
# 0    3R    SF     W     W    4R   SF      A   6 / 21  102–15   87%
# 1    QF     A     A     A    SF    A  4R[B]   1 / 19   73–17   81%
# 2     F    SF     W    QF     F   NH     QF   8 / 22  105–14   88%
# 3     F     A    QF    4R    QF    A      A   5 / 19   89–14   86%
# 4  18–4  10–2  18–1  14–2  18–4  5–1    7–1  20 / 81  369–60   86%
#
# [5 rows x 27 columns]

# %%
gs_finals = df[4]
gs_finals
# Out:
#    Result  Year           Tournament Surface               Opponent  \
# 0     Win  2003            Wimbledon   Grass     Mark Philippoussis
# 1     Win  2004      Australian Open    Hard            Marat Safin
# 2     Win  2004        Wimbledon (2)   Grass           Andy Roddick
# 3     Win  2004              US Open    Hard         Lleyton Hewitt
# 4     Win  2005        Wimbledon (3)   Grass           Andy Roddick
# 5     Win  2005          US Open (2)    Hard           Andre Agassi
# 6     Win  2006  Australian Open (2)    Hard       Marcos Baghdatis
# 7    Loss  2006          French Open    Clay           Rafael Nadal
# 8     Win  2006        Wimbledon (4)   Grass           Rafael Nadal
# 9     Win  2006          US Open (3)    Hard           Andy Roddick
# 10    Win  2007  Australian Open (3)    Hard      Fernando González
# 11   Loss  2007          French Open    Clay           Rafael Nadal
# 12    Win  2007        Wimbledon (5)   Grass           Rafael Nadal
# ...

# %%
nba_df = pd.read_html("https://es.wikipedia.org/wiki/National_Basketball_Association")

# %%
nba_df[5].columns
# Out:
# MultiIndex([(          'Temporada', 'Basketball Association of America (BAA)'),
#             (            'Campeón', 'Basketball Association of America (BAA)'),
#             (          'Resultado', 'Basketball Association of America (BAA)'),
#             (         'Subcampeón', 'Basketball Association of America (BAA)'),
#             ( 'MVP de las Finales', 'Basketball Association of America (BAA)'),
#             ('MVP de la Temporada', 'Basketball Association of America (BAA)'),
#             ( 'Entrenador del Año', 'Basketball Association of America (BAA)')],
#            )

# %%
nba_df[5]
# Out:
#                                  Temporada  \
#    Basketball Association of America (BAA)
# 0                                  1946-47
# 1                                  1947-48
# 2                                  1948-49
# 3    National Basketball Association (NBA)
# 4                                  1949-50
# ..                                     ...
# 72                                 2017-18
# 73                                 2018-19
# 74                                 2019-20
# 75                                 2020-21
# 76                                 2021-22
#
#                                    Campeón  \
#    Basketball Association of America (BAA)
# 0                  Philadelphia Warriors *
# 1                        Baltimore Bullets
# 2                     Minneapolis Lakers *
# 3    National Basketball Association (NBA)
# 4                     Minneapolis Lakers *
# ..                                     ...
# 72                   Golden State Warriors
# ...

# %%
nba_df[5][["Campeón","Temporada"]]
# Out:
#                                    Campeón  \
#    Basketball Association of America (BAA)
# 0                  Philadelphia Warriors *
# 1                        Baltimore Bullets
# 2                     Minneapolis Lakers *
# 3    National Basketball Association (NBA)
# 4                     Minneapolis Lakers *
# ..                                     ...
# 72                   Golden State Warriors
# 73                         Toronto Raptors
# 74                      Los Angeles Lakers
# 75                         Milwaukee Bucks
# 76                   Golden State Warriors
#
#                                  Temporada
#    Basketball Association of America (BAA)
# 0                                  1946-47
# 1                                  1947-48
# 2                                  1948-49
# 3    National Basketball Association (NBA)
# 4                                  1949-50
# ..                                     ...
# 72                                 2017-18
# ...
