# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
from langdetect import detect

# %%
file = "data/political_social_media.csv"
political_posts = pd.read_csv(file, encoding_errors = "ignore", usecols= ['_unit_id',
       '_last_judgment_at', 'audience', 'bias', 'message', 'bioid', 'id', 'label', 'source', 'text'])
political_posts.head(2)
# Out:
#     _unit_id _last_judgment_at  audience      bias message    bioid  \
# 0  766192484      8/4/15 21:17  national  partisan  policy  R000596
# 1  766192485      8/4/15 21:20  national  partisan  attack  M000355
#
#             id                                           label   source  \
# 0  3.83249E+17  From: Trey Radel (Representative from Florida)  twitter
# 1  3.11208E+17   From: Mitch McConnell (Senator from Kentucky)  twitter
#
#                                                 text
# 0  RT @nowthisnews: Rep. Trey Radel (R- #FL) slam...
# 1  VIDEO - #Obamacare:  Full of Higher Costs and ...

# %%
political_posts.shape
# Out:
# (5000, 10)

# %%
political_posts.columns
# Out:
# Index(['_unit_id', '_last_judgment_at', 'audience', 'bias', 'message', 'bioid',
#        'id', 'label', 'source', 'text'],
#       dtype='object')

# %%
political_posts.rename(columns={'_unit_id': 'unit_id', '_last_judgment_at': 'last_judgment_date', 'bioid': 'politico_id','id': 'mensaje_id_sitio' }, inplace=True)
political_posts.columns
# Out:
# Index(['unit_id', 'last_judgment_date', 'audience', 'bias', 'message',
#        'politico_id', 'mensaje_id_sitio', 'label', 'source', 'text'],
#       dtype='object')

# %%
political_posts.dtypes
# Out:
# unit_id                int64
# last_judgment_date    object
# audience              object
# bias                  object
# message               object
# politico_id           object
# mensaje_id_sitio      object
# label                 object
# source                object
# text                  object
# dtype: object

# %%
political_posts.last_judgment_date = pd.to_datetime(political_posts.last_judgment_date)
political_posts.dtypes
# Out:
# unit_id                        int64
# last_judgment_date    datetime64[ns]
# audience                      object
# bias                          object
# message                       object
# politico_id                   object
# mensaje_id_sitio              object
# label                         object
# source                        object
# text                          object
# dtype: object

# %%
print(f"El periodo que se analizaron las publicaciones fue desde:{min(political_posts.last_judgment_date)}, hasta: {max(political_posts.last_judgment_date)}")
# Out:
# El periodo que se analizaron las publicaciones fue desde:2015-08-04 20:02:00, hasta: 2015-08-05 14:55:00

# %%
political_posts.isna().sum()
# Out:
# unit_id               0
# last_judgment_date    0
# audience              0
# bias                  0
# message               0
# politico_id           0
# mensaje_id_sitio      0
# label                 0
# source                0
# text                  0
# dtype: int64

# %% [markdown]
# Durante este periodo, el presidente de los Estados UNidos era Barack Obama, siendo parte del partido Democrata

# %%
political_posts.message.unique()
# Out:
# array(['policy', 'attack', 'support', 'information', 'mobilization',
#        'personal', 'other', 'constituency', 'media'], dtype=object)

# %% [markdown]
# Creo la columna: cantidad de palabras, para ver si luego encuentro una relacione entre esto y la intencion del mensaje

# %%
political_posts['cantidad_caracteres'] = political_posts.text.str.len()
political_posts.head()
# Out:
#      unit_id  last_judgment_date  audience      bias  message politico_id  \
# 0  766192484 2015-08-04 21:17:00  national  partisan   policy     R000596
# 1  766192485 2015-08-04 21:20:00  national  partisan   attack     M000355
# 2  766192486 2015-08-04 21:14:00  national   neutral  support     S001180
# 3  766192487 2015-08-04 21:08:00  national   neutral   policy     C000880
# 4  766192488 2015-08-04 21:26:00  national  partisan   policy     U000038
#
#   mensaje_id_sitio                                             label   source  \
# 0      3.83249E+17    From: Trey Radel (Representative from Florida)  twitter
# 1      3.11208E+17     From: Mitch McConnell (Senator from Kentucky)  twitter
# 2      3.39069E+17  From: Kurt Schrader (Representative from Oregon)  twitter
# 3      2.98528E+17          From: Michael Crapo (Senator from Idaho)  twitter
# 4      4.07643E+17          From: Mark Udall (Senator from Colorado)  twitter
#
#                                                 text  cantidad_caracteres
# 0  RT @nowthisnews: Rep. Trey Radel (R- #FL) slam...                   93
# 1  VIDEO - #Obamacare:  Full of Higher Costs and ...                   85
# 2  Please join me today in remembering our fallen...                  136
# 3  RT @SenatorLeahy: 1st step toward Senate debat...                  122
# 4  .@amazon delivery #drones show need to update ...                  143

# %%
political_posts.describe()
# Out:
#             unit_id  cantidad_caracteres
# count  5.000000e+03          5000.000000
# mean   7.661950e+08           204.396400
# std    1.444060e+03           301.226757
# min    7.661925e+08             1.000000
# 25%    7.661937e+08           112.000000
# 50%    7.661950e+08           137.000000
# 75%    7.661962e+08           205.000000
# max    7.661975e+08         14344.000000

# %%
fig = plt.figure(figsize =(15, 7))
plt.boxplot(political_posts.cantidad_caracteres)
plt.show()

# %%
posibles_outliers = political_posts[political_posts.cantidad_caracteres > 280]      #280 es el limite de caracteres en twitter
posibles_outliers
# Out:
#         unit_id  last_judgment_date  audience      bias      message  \
# 2501  766194987 2015-08-05 04:43:00  national   neutral  information
# 2503  766194989 2015-08-05 05:40:00  national   neutral       policy
# 2504  766194990 2015-08-05 05:40:00  national   neutral       policy
# 2505  766194991 2015-08-05 05:13:00  national   neutral       policy
# 2506  766194992 2015-08-05 06:02:00  national  partisan       policy
# ...         ...                 ...       ...       ...          ...
# 4992  766197479 2015-08-05 05:36:00  national   neutral        media
# 4994  766197481 2015-08-05 05:39:00  national   neutral     personal
# 4995  766197482 2015-08-05 06:05:00  national  partisan      support
# 4996  766197483 2015-08-05 05:57:00  national  partisan       policy
# 4997  766197484 2015-08-05 05:10:00  national   neutral       policy
#
#      politico_id                  mensaje_id_sitio  \
# 2501     A000055     19787529402_10151438053704403
# 2503     A000360     89927603836_10151473528428837
# 2504     A000360     89927603836_10102170734377750
# 2505     A000367   173604349345646_858910437481697
# 2506     A000367   173604349345646_727641740608568
# ...          ...                               ...
# 4992     Y000064   186203844738421_278220632312018
# 4994     Y000065  563532937006022_1005685512790760
# 4995     Y000065   563532937006022_939071892785456
# 4996     Y000065   563532937006022_936080056417973
# 4997     Y000065   563532937006022_905547326137913
#
#                                                   label    source  \
# 2501  From: Robert Aderholt (Representative from Ala...  facebook
# 2503     From: Lamar Alexander (Senator from Tennessee)  facebook
# 2504     From: Lamar Alexander (Senator from Tennessee)  facebook
# 2505  From: Justin Amash (Representative from Michigan)  facebook
# 2506  From: Justin Amash (Representative from Michigan)  facebook
# ...                                                 ...       ...
# 4992     From: Todd Young (Representative from Indiana)  facebook
# 4994       From: Ted Yoho (Representative from Florida)  facebook
# 4995       From: Ted Yoho (Representative from Florida)  facebook
# 4996       From: Ted Yoho (Representative from Florida)  facebook
# 4997       From: Ted Yoho (Representative from Florida)  facebook
#
#                                                    text  cantidad_caracteres
# 2501  In today۪s challenging budgetary environment, ...                  466
# 2503  ICYMI: Sen. Alexander on Saturday delivered th...                  628
# 2504  ICYMI: On the Senate floor yesterday, Sen. Ale...                  442
# 2505  I voted yes on #HR2, American Energy Solutions...                  303
# 2506  Congressman Ron DeSantis endorses Rep. Ra̼l R....                 1234
# ...                                                 ...                  ...
# 4992  Take a look at a recent article in the Corydon...                  307
# 4994  I was honored to host the Discovery Channel in...                  350
# 4995  I applaud Governor Perry۪s recent decision to ...                  350
# 4996  Today, I voted in favor of H.R. 5016 - Financi...                  841
# 4997  (Taken from posted WOKV interview)   Congressm...                  435
#
# [869 rows x 11 columns]

# %%
posibles_outliers.source.unique()
# Out:
# array(['facebook'], dtype=object)

# %% [markdown]
# Esta cantidad es posible, ya que es una publicacion de facebook, y no hay limitaciones al respecto en esta red social

# %% [markdown]
# Tomo la columna label, y a partir de ella, creo: usuario, cargo y estado. para asi poder analizar por separado

# %%
political_posts['usuario'] = political_posts.label.apply(lambda x: x.split(": ")[1]).apply(lambda x: x.split(" (")[0])
political_posts['cargo'] = political_posts.label.apply(lambda x: x.split("(")[1]).apply(lambda x: x.split(" ")[0])
political_posts['estado'] = political_posts.label.apply(lambda x: x.split("from ")[1]).apply(lambda x: x.split(")")[0])
political_posts.drop('label', inplace=True, axis=1)
political_posts.head()
# Out:
#      unit_id  last_judgment_date  audience      bias  message politico_id  \
# 0  766192484 2015-08-04 21:17:00  national  partisan   policy     R000596
# 1  766192485 2015-08-04 21:20:00  national  partisan   attack     M000355
# 2  766192486 2015-08-04 21:14:00  national   neutral  support     S001180
# 3  766192487 2015-08-04 21:08:00  national   neutral   policy     C000880
# 4  766192488 2015-08-04 21:26:00  national  partisan   policy     U000038
#
#   mensaje_id_sitio   source  \
# 0      3.83249E+17  twitter
# 1      3.11208E+17  twitter
# 2      3.39069E+17  twitter
# 3      2.98528E+17  twitter
# 4      4.07643E+17  twitter
#
#                                                 text  cantidad_caracteres  \
# 0  RT @nowthisnews: Rep. Trey Radel (R- #FL) slam...                   93
# 1  VIDEO - #Obamacare:  Full of Higher Costs and ...                   85
# 2  Please join me today in remembering our fallen...                  136
# 3  RT @SenatorLeahy: 1st step toward Senate debat...                  122
# 4  .@amazon delivery #drones show need to update ...                  143
#
#            usuario           cargo    estado
# 0       Trey Radel  Representative   Florida
# 1  Mitch McConnell         Senator  Kentucky
# 2    Kurt Schrader  Representative    Oregon
# 3    Michael Crapo         Senator     Idaho
# 4       Mark Udall         Senator  Colorado

# %%
political_posts.cargo.unique()
# Out:
# array(['Representative', 'Senator'], dtype=object)

# %%
posts_mensaje_cargo = political_posts.groupby(['message', 'cargo']).agg(
    cantidad_de_posts =  ('unit_id', 'count')).pivot_table( values='cantidad_de_posts', index=['message'],columns=['cargo']).apply(lambda x: x/x.sum() * 100)
posts_mensaje_cargo
# Out:
# cargo         Representative    Senator
# message
# attack              3.527950   3.076923
# constituency        3.229814   2.256410
# information        13.341615  11.282051
# media               5.416149   6.051282
# mobilization        2.608696   2.461538
# other               2.633540   1.538462
# personal           23.975155  21.025641
# policy             27.155280  32.615385
# support            18.111801  19.692308

# %%
political_posts.estado.value_counts()
# Out:
# Texas             494
# California        486
# Florida           298
# New York          224
# Ohio              183
# 1004  My interview w/ @NiaWaPo on @PostTV, discussin...                  108
# 1440  Government-to-Go: Need help with a federal age...                  138
# 2612  I continue to accept applications for nominati...                  308
# 2613  Congresswoman Bordallo joins Members of Congre...                  267
# 2614  I am deeply saddened at the loss of SGT Eugene...                  428
# 4237  En breve AL AIRE junto a Kike Cruz por Notiuno...                   52
# 4238  @ Fideicomiso de Conservaci_nPR revisando los ...                  116
# 4239  http://www.metro.pr/locales/guardia-costera-co...                  107
# 4240  Los pagos de hospitalizaci_n promedio de Medic...                  525
# 4241  En breve estar̩ en el hemiciclo de la Cmara de...                  213
# 4242  Llegando a reunirme con el Presidente Bill Cli...                   50
# 4243  El Departamento de Seguridad Interna de Estado...                  521
# 4244  Compartiendo con la Asociaci_n Nacional de Con...                  303
# 4245  En la toma de posesi_n del alcalde Isabelo "Ch...                  113
# 4623  A 6.8 magnitude earthquake occurred off the ea...                  250
# 4624  Occupational Health Nurse  The Department of t...                  417
# 4625  Women and Minorities in STEM Fields Program  T...                  526
# 4626  Human Resources Specialist - The Department of...                  612
#
#                                  usuario           cargo estado
# 118                       Eleanor Norton  Representative     NA
# 1004                      Eleanor Norton  Representative     NA
# 1440                      Eleanor Norton  Representative     NA
# 2612                  Madeleine Bordallo  Representative     NA
# 2613                  Madeleine Bordallo  Representative     NA
# 2614                  Madeleine Bordallo  Representative     NA
# 4237                     Pedro Pierluisi  Representative     NA
# 4238                     Pedro Pierluisi  Representative     NA
# 4239                     Pedro Pierluisi  Representative     NA
# 4240                     Pedro Pierluisi  Representative     NA
# 4241                     Pedro Pierluisi  Representative     NA
# 4242                     Pedro Pierluisi  Representative     NA
# 4243                     Pedro Pierluisi  Representative     NA
# 4244                     Pedro Pierluisi  Representative     NA
# 4245                     Pedro Pierluisi  Representative     NA
# 4623  Gregorio &#x27;Kilili&#x27; Sablan  Representative     NA
# 4624  Gregorio &#x27;Kilili&#x27; Sablan  Representative     NA
# 4625  Gregorio &#x27;Kilili&#x27; Sablan  Representative     NA
# 4626  Gregorio &#x27;Kilili&#x27; Sablan  Representative     NA

# %% [markdown]
# Según la Constitución de EE.UU., sólo los estados pueden estar representados en el Congreso de los Estados Unidos, por lo que hay territorios que no tienen representación con derecho a voto.
# En su lugar, los electores del distrito eligen a un delegado sin derecho a voto en la Cámara de Representantes de los Estados Unidos. Y tampoco pueden votar en las elecciones presidenciales.
# Según la Cámara de Representantes de 2015:
# - Eleanor Holmes Norton --> District of Columbia
# - Madeline Bordallo --> Guam
# - Pedro Pierlusi --> Puerto Rico
# - Gregorio 'Kilili' Sablan --> Northern Mariana Islands

# %%
political_posts.loc[political_posts['usuario'] == 'Eleanor Norton', 'estado'] = 'District of Columbia'
political_posts.loc[political_posts['usuario'] == 'Madeleine Bordallo', 'estado'] = 'Guam'
political_posts.loc[political_posts['usuario'] == 'Pedro Pierluisi', 'estado'] = 'Puerto Rico'
political_posts.loc[political_posts['politico_id'] == 'S001177', 'estado'] = 'Northern Mariana Islands'

len(political_posts[political_posts.estado == 'NA'])
# Out:
# 0

# %%
cantidad_de_caracteres_mensaje = political_posts.groupby(['message']).agg(
    promedio_palabras =  ('cantidad_caracteres', 'mean'))
cantidad_de_caracteres_mensaje.sort_values('promedio_palabras', ascending = False)
# Out:
#               promedio_palabras
# message
# policy               248.668320
# support              206.707926
# attack               203.918605
# information          193.548686
# mobilization         187.286822
# personal             180.459829
# constituency         164.611842
# other                162.876033
# media                145.870036

# %%
political_posts.politico_id.nunique()
# Out:
# 505

# %%
def detect_my(text):
    try:
        return detect(text)
    except:
        return "unknown"

political_posts['idioma'] = political_posts['text'].apply(detect_my)
political_posts.head()
# Out:
#      unit_id  last_judgment_date  audience      bias  message politico_id  \
# 0  766192484 2015-08-04 21:17:00  national  partisan   policy     R000596
# 1  766192485 2015-08-04 21:20:00  national  partisan   attack     M000355
# 2  766192486 2015-08-04 21:14:00  national   neutral  support     S001180
# 3  766192487 2015-08-04 21:08:00  national   neutral   policy     C000880
# 4  766192488 2015-08-04 21:26:00  national  partisan   policy     U000038
#
#   mensaje_id_sitio   source  \
# 0      3.83249E+17  twitter
# 1      3.11208E+17  twitter
# 2      3.39069E+17  twitter
# 3      2.98528E+17  twitter
# 4      4.07643E+17  twitter
#
#                                                 text  cantidad_caracteres  \
# 0  RT @nowthisnews: Rep. Trey Radel (R- #FL) slam...                   93
# 1  VIDEO - #Obamacare:  Full of Higher Costs and ...                   85
# 2  Please join me today in remembering our fallen...                  136
# 3  RT @SenatorLeahy: 1st step toward Senate debat...                  122
# 4  .@amazon delivery #drones show need to update ...                  143
#
#            usuario           cargo    estado idioma
# 0       Trey Radel  Representative   Florida     en
# 1  Mitch McConnell         Senator  Kentucky     en
# 2    Kurt Schrader  Representative    Oregon     en
# 3    Michael Crapo         Senator     Idaho     en
# 4       Mark Udall         Senator  Colorado     en

# %%
file_idiomas = "data/idiomas.csv"
idiomas = pd.read_csv(file_idiomas)
idiomas.head()
# Out:
#   language_name idioma
# 0     Abkhazian     ab
# 1          Afar     aa
# 2     Afrikaans     af
# 3          Akan     ak
# 4      Albanian     sq

# %%
political_posts = pd.merge(political_posts, idiomas, how='left')
political_posts.drop('idioma', inplace=True, axis=1)
political_posts.language_name.value_counts()
# Out:
# English                            4907
# Spanish , Castilian                  37
# German                                8
# Dutch , Flemish                       7
# Afrikaans                             5
# Catalan , Valencian                   3
# Italian                               3
# Somali                                2
# French                                2
# Slovenian                             2
# Tagalog                               2
# Swedish                               1
# Danish                                1
# Norwegian                             1
# Croatian                              1
# Welsh                                 1
# Finnish                               1
# Romanian , Moldavian , Moldovan       1
# Portuguese                            1
# Turkish                               1
# Latvian                               1
# Vietnamese                            1
# Name: language_name, dtype: int64

# %%
political_posts[political_posts.language_name.isna()].text
# Out:
# 432         http://t.co/Jj6T4Vk12x http://t.co/uE9KF7DQrF
# 2823                                              2/11/14
# 2874    http://www.politico.com/story/2014/08/lacy-cla...
# 3271                          http://youtu.be/cv1fjOWJDAE
# 3762                                                    .
# 3849                          http://youtu.be/Dn93xkYBnMk
# 3861                          http://youtu.be/TOsyw3X5wOI
# 4231    http://www.nydailynews.com/new-york/rangel-chi...
# 4250    https://www.youtube.com/watch?v=IJRAZWGYykM&fe...
# 4552     http://sessions.house.gov/index.cfm/weekly-ne...
# 4917    http://womack.congressnewsletter.net/mail/util...
# Name: text, dtype: object

# %% [markdown]
# Se debe a que son links o hay un punto (seguramente haciendo referencia a un reposteo), o hay una fecha.

# %%
political_posts[political_posts.text == '.']
# Out:
#         unit_id  last_judgment_date  audience      bias message politico_id  \
# 3762  766196248 2015-08-05 06:00:00  national  partisan  policy     L000263
#
#                       mensaje_id_sitio    source text  cantidad_caracteres  \
# 3762  223726364320243_1090155251010679  facebook    .                    1
#
#            usuario           cargo    estado language_name
# 3762  Sander Levin  Representative  Michigan           NaN

# %%
political_posts[political_posts.text == '2/11/14']
# Out:
#         unit_id  last_judgment_date  audience     bias   message politico_id  \
# 2823  766195309 2015-08-05 05:54:00  national  neutral  personal     C001056
#
#                    mensaje_id_sitio    source     text  cantidad_caracteres  \
# 2823  75755694423_10152211852589424  facebook  2/11/14                    7
#
#           usuario    cargo estado language_name
# 2823  John Cornyn  Senator  Texas           NaN

# %% [markdown]
# Es un mensaje personal, entonces debe tener una conexión con la persona

# %%
political_posts_not_english = political_posts[political_posts.language_name != 'English']
political_posts_not_english[['text', 'language_name']]
# Out:
#                                                    text        language_name
# 55    Demandar Obama un recuento en #Venezuela? Creo...  Spanish , Castilian
# 167   Apropiado q Maduro + Ortega juntos en #Nicarag...  Spanish , Castilian
# 169           @dwaynebenji Thank you so much Dwayne!!!!               Somali
# 171   Senator Obama debates President Obama: http://...  Catalan , Valencian
# 176                  @et_disclosure I got your message.               French
# ...                                                 ...                  ...
# 4552   http://sessions.house.gov/index.cfm/weekly-ne...                  NaN
# 4727  Estamos celebrando Cinco de Mayo in Hayward w/...  Spanish , Castilian
# 4826  Viva Mexico! Have a happy Mexican Independence...  Spanish , Castilian
# 4917  http://womack.congressnewsletter.net/mail/util...                  NaN
# 4924                 LISTEN NOW! http://t.co/iYLkRZOGBB           Vietnamese
#
# [93 rows x 2 columns]

# %% [markdown]
# Me di cuenta que todos lso textos que aparecian en otro idioma qu eno fuese ingles en la columna 'language name', realmente estaban en ingles, era solo por el nombre de las personas que lo cambiaban

# %%
political_posts["language_name"] = np.where(political_posts["language_name"].isna(), "Desconocido", political_posts["language_name"])
political_posts["language_name"] = np.where((political_posts["language_name"] != 'English') & (political_posts["language_name"] != 'Desconocido') & (political_posts["language_name"] != 'Spanish , Castilian'), "English", political_posts["language_name"])
posts_español = political_posts[political_posts.language_name == 'Spanish , Castilian']
posts_español
# Out:
#         unit_id  last_judgment_date      audience      bias       message  \
# 55    766192539 2015-08-04 20:44:00      national  partisan        attack
# 167   766192652 2015-08-04 21:12:00      national  partisan        policy
# 287   766192772 2015-08-04 20:26:00      national   neutral         media
# 395   766192880 2015-08-04 21:07:00      national   neutral       support
# 1023  766193508 2015-08-04 20:58:00  constituency   neutral      personal
# 1167  766193652 2015-08-04 21:10:00      national   neutral   information
# 1294  766193779 2015-08-04 21:02:00      national   neutral      personal
# 1423  766193908 2015-08-04 21:25:00      national   neutral        policy
# 1514  766193999 2015-08-04 20:20:00  constituency  partisan         media
# 1617  766194102 2015-08-04 21:22:00  constituency   neutral  constituency
# 1643  766194128 2015-08-04 21:22:00      national   neutral         other
# 4358     R000435  286546974761109_610474702368333  facebook
# 4359     R000435  286546974761109_607889839293486  facebook
# 4727     S001193  450130878375355_502547886466987  facebook
# 4826     V000131  394849110600016_678052215613036  facebook
#
#                                                    text  cantidad_caracteres  \
# 55    Demandar Obama un recuento en #Venezuela? Creo...                  139
# 167   Apropiado q Maduro + Ortega juntos en #Nicarag...                  135
# 287   Placer reunirme c la directora de @NTN24 @CGur...                  140
# 395   RT @TelemundoNews: La congresista Ileana @RosL...                  140
# 1023                        My pleasure!!!  @deciminyan                   27
# 1167  Update: Las Vegas man vandalizes El Paso billb...                  104
# 1294  We shall pray!@antunezcuba: 8:27 pm, info Dama...                  134
# 1423  Me uno a todos en PR en pro de la liberacion d...                  140
# 1514  Vean domingo @ 1130am p oir sobre mi viaje a #...                  140
# 1617  Wonderful costumes @ #DiadelosMuertos festival...                   86
# 1643  RT @eduardobhatia: Extraordinaria entrevista d...                  140
# 1694  RT @LeninPR: Ma̱ana no te pierdas Pegaos a las...                  140
# 1755  Fueron Jay-Z y Beyonce otorgados licencia p vi...                  139
# 2291  AHORA: en vivo @FoxNews p hablar sobre acuerdo...                  138
# 2567                           Texas continues to lead!                   24
# 2991  Las familias del Valle de San Fernando pueden ...                  439
# 2998  Se hacen entrevistas de trabajo all_ mismo par...                  100
# 3001  Nada podr reemplazar el da̱o y las vidas perdi...                  288
# 3360  El congresista Luis Guti̩rrez acerca de la #Re...                  164
# 4219                      La Gran D radio in Las Cruces                   29
# 4238  @ Fideicomiso de Conservaci_nPR revisando los ...                  116
# 4240  Los pagos de hospitalizaci_n promedio de Medic...                  525
# 4241  En breve estar̩ en el hemiciclo de la Cmara de...                  213
# 4242  Llegando a reunirme con el Presidente Bill Cli...                   50
# 4243  El Departamento de Seguridad Interna de Estado...                  521
# 4244  Compartiendo con la Asociaci_n Nacional de Con...                  303
# 4245  En la toma de posesi_n del alcalde Isabelo "Ch...                  113
# 4332  En @ActualidadRadio @msfernandanews @napoleonb...                  138
# 4335  Hable c @PedaleaBernie en @radiomambi710 sbr v...                  140
# 4336  La lucha por una #Cuba libre no descansa c/@Ma...                  106
# 4339  En @americateve_an dije q tenemos q seguir apo...                  135
# 4344  Dije @ernestorios786 q es un momento cr_tico p...                  140
# 4351  .@MarioDB y yo le dijimos a @MichelJMartelly q...                  127
# 4358  Desafortunadamente #venezolanos han muerto por...                  139
# 4359  Habl̩ con @Telemundo51 sobre huelga de hambre ...                  140
# 4727  Estamos celebrando Cinco de Mayo in Hayward w/...                   95
# 4826  Viva Mexico! Have a happy Mexican Independence...                  129
#
#                   usuario           cargo       estado        language_name
# 55    Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 167   Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 287   Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 395   Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 1023          Cory Booker         Senator   New Jersey  Spanish , Castilian
# 1167          John Cornyn         Senator        Texas  Spanish , Castilian
# 1294  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 1423         Jos̩ Serrano  Representative     New York  Spanish , Castilian
# 1514  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 1617           Dina Titus  Representative       Nevada  Spanish , Castilian
# 1643         Jos̩ Serrano  Representative     New York  Spanish , Castilian
# 1694         Jos̩ Serrano  Representative     New York  Spanish , Castilian
# 1755  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 2291  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 2567          Kevin Brady  Representative        Texas  Spanish , Castilian
# 2991        Tony Cardenas  Representative   California  Spanish , Castilian
# 2998        Tony Cardenas  Representative   California  Spanish , Castilian
# 3001        Tony Cardenas  Representative   California  Spanish , Castilian
# 3360       Luis Gutierrez  Representative     Illinois  Spanish , Castilian
# 4219         Steve Pearce  Representative   New Mexico  Spanish , Castilian
# 4238      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4240      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4241      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4242      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4243      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4244      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4245      Pedro Pierluisi  Representative  Puerto Rico  Spanish , Castilian
# 4332  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4335  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4336  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4339  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4344  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4351  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4358  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4359  Ileana Ros-Lehtinen  Representative      Florida  Spanish , Castilian
# 4727        Eric Swalwell  Representative   California  Spanish , Castilian
# 4826          Marc Veasey  Representative        Texas  Spanish , Castilian

# %%
posts_español.estado.value_counts()
# Out:
# Florida        16
# Puerto Rico     7
# California      4
# Texas           3
# New York        3
# New Jersey      1
# Nevada          1
# Illinois        1
# New Mexico      1
# Name: estado, dtype: int64

# %% [markdown]
# ## Analisis segun los tipos de mensajes

# %% [markdown]
# Cantidad de mensajes por intencion

# %%
political_posts['message'].value_counts()
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
ax = sns.countplot(data = political_posts, x = 'message',
              order = political_posts['message'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

ax.set_title('Cantidad de mensajes por intencion')
plt.show()

# %% [markdown]
# clasificaiocn de tipos de publicaciones segun la audiencia a la que apunta

# %%
segun_audiencia = pd.crosstab(political_posts['message'],political_posts['audience']).apply(lambda x: x/x.sum()*100)
segun_audiencia
# Out:
# audience      constituency   national
# message
# attack            0.583090   4.180307
# constituency     13.605442   0.302191
# information      20.408163  11.004785
# media             6.122449   5.389071
# mobilization      4.081633   2.190884
# other             1.360544   2.694535
# personal         31.098154  21.405188
# policy           15.257532  31.578947
# support           7.482993  21.254092

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
segun_audiencia[['constituency','national']].plot(kind ='barh', stacked=True,color = ("#e9a3c9", "#a1d76a"))

plt.show()

# %%
political_posts_attack = political_posts[political_posts['message'] == "attack"]
political_posts_support = political_posts[political_posts['message']=="support"]
political_posts_policy = political_posts[political_posts['message']=="policy"]
political_posts_information = political_posts[political_posts['message']=="information"]
political_posts_mobilization = political_posts[political_posts['message']=="mobilization"]
political_posts_personal = political_posts[political_posts['message']=="personal"]
political_posts_constituency = political_posts[political_posts['message']=="constituency"]
political_posts_media = political_posts[political_posts['message']=="media"]
political_posts_other = political_posts[political_posts['message']=="other"]

# %% [markdown]
# De donde salieron las publicaciones segun la intencion de las mimsas

# %%
plt.rcParams.update({'figure.figsize':(7.5,7), 'figure.dpi':150})
fig, axes = plt.subplots(nrows=3, ncols=3)
political_posts_attack.source.value_counts().plot(ax=axes[0,0], kind ='pie', title = 'Posts de ataque',autopct='%1.0f%%', colors = ['steelblue', 'blue'])
political_posts_support.source.value_counts().plot(ax=axes[0,1],kind ='pie', title = 'Posts de apoyo',autopct='%1.0f%%', colors = ['steelblue', 'blue'])
political_posts_policy.source.value_counts().plot(ax=axes[0,2],kind ='pie', title = 'Posts de politicas',autopct='%1.0f%%', colors = ['blue', 'steelblue'])
political_posts_mobilization.source.value_counts().plot(ax=axes[1,0],kind ='pie', title = 'Posts de movilizacion',autopct='%1.0f%%', colors = ['steelblue', 'blue'])
political_posts_information.source.value_counts().plot(ax=axes[1,1],kind ='pie', title = 'Posts de info',autopct='%1.0f%%', colors = ['steelblue', 'blue'])
political_posts_personal.source.value_counts().plot(ax=axes[1,2],kind ='pie', title = 'Posts personales',autopct='%1.0f%%', colors = [ 'blue', 'steelblue',])
political_posts_constituency.source.value_counts().plot(ax=axes[2,0],kind ='pie', title = 'Posts circunscriptos',autopct='%1.0f%%', colors = ['steelblue', 'blue'])
political_posts_media.source.value_counts().plot(ax=axes[2,1],kind ='pie', title = 'Posts hacia media',autopct='%1.0f%%', colors = ['steelblue', 'blue'])
political_posts_other.source.value_counts().plot(ax=axes[2,2],kind ='pie', title = 'Posts otros',autopct='%1.0f%%', colors = [ 'blue', 'steelblue'])
fig.suptitle('Las fuentes de los..', fontsize=12)
plt.show()

# %% [markdown]
# ### Attack

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_attack.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Las palabras mas utilizadas en estas publicaciones, refieren a politicas o programas implementados durante la presidencia corriente (de Obama) y el nombre del dirigente es mencionado repetidas veces. Y tambien refieren a problemas o cuestiones del momento.
# Algunas palabras que aparecen con ciertas connotaciones negativas son: costs, higher, stuck, spawning.
# Es curioso que tambien aparece Venezuela, dentro de lso mensajes de ataque como critica (elemento que se podria transpolar a la situacion argentina)

# %% [markdown]
# ### Support

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_support.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# En los mensajes de apoyo a otros politicos, podemos encontrar palabaras con connotaciones mas positivas y con intenciones de "unir" o "amigar": join, please,  great, vote, share, applaud.
# Y tambien en visperas de las eleccioes del 2016, vemos que aparece "Clinton", con referencia al apoyo a su candidatura en las proximas elecciones.

# %% [markdown]
# ### Mobilization

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_mobilization.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Las palabras que mas aparecen estan relacionadas a "llamados de ayuda" o "llamados a colaborar o a sumarse": help, rt, together, want, keep.
# Y tambien aparecen situaciones que requieren el apoyo de la sociedad y de su movilizacion para que todos se enteren como la crisis social que sucedia en Nigeria, con los secuestros qeu pasaban y los atentados.
# Ademas, aparece el nombre de un sitio de noticias conocido: BBCWorld

# %% [markdown]
# ### Policy

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_policy.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# En este caso aparecen bastantes nombres de politicos y se refiere a varias palabras relacionadas al sistema politico y al proceso de creacion de nuevas leyes

# %% [markdown]
# ### Personal

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_personal.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Information

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_information.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# En los textos informativos, se utilizan palabras de "notica": week, info, release, hall + town. Tambien aparece el nombre de cuentas oficiales informativas del gobierno(USDOTFRA: Federal Railroad Administration)

# %% [markdown]
# ### Constituency

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_constituency.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Es mas dificil identificiar, ya que consituency refiere a mensajes con la intenncion de apuntar al ambito "local" del politico.
# Ciertas palabras aprticulaes son: nombres de estados, farm, parks.

# %% [markdown]
# ### Media

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_media.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Cuando lso mensajes implican una relacion con los medios de comunicacion, aprecen los nombres de lso portales de noticias, nombres de periodistas, y palabras como:show, coffee, radio, article, morning, shortly.

# %% [markdown]
# ### Other

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(political_posts_other.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Podemos ver como, se tratan temas varios, y temas que no implican una confrontacion o la neceisdad de apoyo o movilizacion. Palabras: American, celebraiting, bday, photo. Y tambien aparece el nombre de Neil Amstrong, y la palabra armstrong, que seguramente se debio a que la muestra de las publicaciones se habra tomado en alguna fecha en relacion con eso.

# %% [markdown]
# #### Analizar el sesgo en relacion con los tipos de publicaciones

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
political_posts_attack.bias.value_counts().plot(ax=axes[0], kind ='pie', title= 'Sesgo de los posts de ataque')
political_posts_support.bias.value_counts().plot(ax=axes[1],kind ='pie', title= 'Sesgo de los posts apoyo')
plt.show()

# %%
partisian = political_posts[political_posts.bias == "partisan"]
neutral = political_posts[political_posts.bias == "neutral"]

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(neutral.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            min_font_size = 10).generate(str(partisian.text))

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
segun_estado = pd.crosstab(political_posts['estado'],political_posts['message']).apply(lambda x: x/x.sum()*100)
segun_estado
# Out:
# message                      attack  constituency  information     media  \
# estado
# Alabama                    0.581395      2.631579     1.854714  2.888087
# Alaska                     0.000000      0.000000     0.309119  0.361011
# Arizona                    3.488372      2.631579     4.018547  3.249097
# Arkansas                   0.000000      2.631579     2.163833  2.527076
# California                11.046512      7.236842     9.582689  6.137184
# Colorado                   1.162791      0.657895     2.163833  1.444043
# Connecticut                0.000000      1.315789     1.391036  0.722022
# Delaware                   0.581395      0.000000     0.154560  0.722022
# District of Columbia       0.000000      0.000000     0.154560  0.000000
# Florida                    5.232558      6.578947     3.400309  6.498195
# Georgia                    2.906977      0.657895     1.391036  2.527076
# Guam                       0.000000      0.000000     0.000000  0.000000
# Hawaii                     0.000000      0.000000     0.154560  0.722022
# Idaho                      0.000000      0.657895     1.236476  1.805054
# Illinois                   4.651163      4.605263     3.400309  3.610108
# Indiana                    4.069767      5.263158     2.472952  3.971119
# Iowa                       1.162791      1.315789     0.772798  0.722022
# Kansas                     2.906977      0.657895     1.391036  2.527076
# Kentucky                   4.069767      0.657895     1.545595  3.610108
# Louisiana                  8.139535      2.631579     2.936631  0.361011
# Maine                      0.000000      0.000000     0.309119  0.361011
# Maryland                   2.325581      0.657895     2.009274  1.444043
# Massachusetts              0.581395      1.973684     1.081917  1.083032
# Michigan                   1.744186      1.973684     2.009274  3.610108
# Minnesota                  0.000000      1.973684     2.472952  1.805054
# Mississippi                0.000000      0.657895     0.463679  1.083032
# Missouri                   1.744186      2.631579     2.627512  1.805054
# Montana                    0.000000      0.000000     0.309119  0.000000
# Nebraska                   0.000000      0.657895     0.618238  1.083032
# Nevada                     0.581395      1.973684     1.081917  0.361011
# New Hampshire              0.581395      1.973684     0.618238  1.083032
# New Jersey                 1.744186      3.289474     1.545595  1.444043
# New Mexico                 0.581395      0.000000     2.009274  0.361011
# New York                   4.069767      6.578947     4.636785  2.888087
# North Carolina             3.488372      1.315789     2.009274  2.166065
# North Dakota               0.000000      1.973684     1.545595  1.444043
# Northern Mariana Islands   0.000000      0.657895     0.154560  0.000000
# Ohio                       2.906977      5.921053     4.173107  3.610108
# Oklahoma                   0.581395      0.000000     0.463679  0.361011
# Oregon                     0.000000      1.315789     1.081917  0.722022
# Pennsylvania               5.232558      2.631579     5.100464  1.444043
# Puerto Rico                0.000000      0.000000     0.309119  0.361011
# Rhode Island               0.581395      2.631579     0.463679  1.083032
# South Carolina             1.744186      1.315789     1.081917  1.444043
# South Dakota               0.581395      1.973684     0.618238  0.000000
# Tennessee                  2.325581      2.631579     1.391036  3.249097
# Texas                     13.372093      7.894737    10.664606  9.386282
# Washington                    3.100775   0.000000   1.367521   1.771793
# West Virginia                 0.000000   0.826446   0.854701   0.992204
# Wisconsin                     1.550388   0.826446   0.512821   1.700921
# Wyoming                       0.000000   0.000000   0.341880   0.921332
#
# message                     support
# estado
# Alabama                    1.194354
# Alaska                     0.434311
# Arizona                    2.714441
# Arkansas                   2.062975
# California                10.206298
# Colorado                   1.520087
# Connecticut                1.954397
# Delaware                   0.434311
# District of Columbia       0.108578
# Florida                    6.731813
# Georgia                    1.194354
# Guam                       0.108578
# Hawaii                     0.325733
# Idaho                      0.760043
# Illinois                   3.691640
# Indiana                    1.845820
# Iowa                       0.760043
# Kansas                     2.171553
# Kentucky                   1.628664
# Louisiana                  1.954397
# Maine                      0.217155
# Maryland                   2.605863
# Massachusetts              3.040174
# Michigan                   1.845820
# Minnesota                  1.520087
# Mississippi                0.760043
# Missouri                   1.411509
# Montana                    0.325733
# Nebraska                   0.325733
# Nevada                     0.868621
# New Hampshire              0.977199
# New Jersey                 2.280130
# New Mexico                 0.542888
# New York                   5.646037
# North Carolina             2.171553
# North Dakota               1.085776
# Northern Mariana Islands   0.000000
# Ohio                       3.365907
# Oklahoma                   0.434311
# Oregon                     0.651466
# Pennsylvania               3.257329
# Puerto Rico                0.325733
# Rhode Island               1.085776
# South Carolina             1.954397
# South Dakota               0.325733
# Tennessee                  2.388708
# Texas                      7.926167
# Utah                       0.868621
# Vermont                    0.977199
# Virginia                   2.497286
# Washington                 2.714441
# West Virginia              1.411509
# Wisconsin                  2.280130
# Wyoming                    0.108578

# %%
segun_estado[segun_estado.attack == max(segun_estado.attack)]
# Out:
# message     attack  constituency  information     media  mobilization  \
# estado
# Texas    13.372093      7.894737    10.664606  9.386282      9.302326
#
# message    other  personal     policy   support
# estado
# Texas    6.61157  10.34188  10.630758  7.926167

# %%
estado_mensaje = pd.crosstab(political_posts['message'],political_posts['estado']).apply(lambda x: x/x.sum()*100)
estado_mensaje
# Out:
# estado          Alabama     Alaska    Arizona   Arkansas  California  \
# message
# attack         1.298701   0.000000   4.166667   0.000000    3.909465
# constituency   5.194805   0.000000   2.777778   4.761905    2.263374
# information   15.584416   7.692308  18.055556  16.666667   12.757202
# media         10.389610   3.846154   6.250000   8.333333    3.497942
# mobilization   2.597403   0.000000   1.388889   2.380952    2.674897
# other          5.194805   0.000000  10.416667   3.571429    3.292181
# personal      23.376623  30.769231  18.055556  23.809524   26.748971
# policy        22.077922  42.307692  21.527778  17.857143   25.514403
# support       14.285714  15.384615  17.361111  22.619048   19.341564
#
# estado         Colorado  Connecticut   Delaware  District of Columbia  \
# message
# attack         2.777778     0.000000   3.703704              0.000000
# constituency   1.388889     2.409639   0.000000              0.000000
# information   19.444444    10.843373   3.703704             33.333333
# media          5.555556     2.409639   7.407407              0.000000
# mobilization   0.000000     1.204819   0.000000              0.000000
# other          1.388889     2.409639   0.000000              0.000000
# personal      22.222222    30.120482  44.444444             33.333333
# policy        27.777778    28.915663  25.925926              0.000000
# support       19.444444    21.686747  14.814815             33.333333
#
# estado          Florida  ...  South Dakota  Tennessee      Texas       Utah  \
# message                  ...
# attack         3.020134  ...      5.555556   3.571429   4.655870   5.263158
# constituency   3.355705  ...     16.666667   3.571429   2.429150   5.263158
# information    7.382550  ...     22.222222   8.035714  13.967611  13.157895
# media          6.040268  ...      0.000000   8.035714   5.263158   2.631579
# mobilization   3.691275  ...      0.000000   4.464286   2.429150   5.263158
# other          1.342282  ...      5.555556   1.785714   1.619433   2.631579
# personal      23.825503  ...     22.222222  17.857143  24.493927  15.789474
# policy        30.536913  ...     11.111111  33.035714  30.364372  28.947368
# support       20.805369  ...     16.666667  19.642857  14.777328  21.052632
#
# estado          Vermont   Virginia  Washington  West Virginia  Wisconsin  \
# message
# attack         1.785714   0.826446    1.176471       3.773585   2.898551
# constituency   0.000000   0.000000    3.529412       0.000000   2.898551
# information   10.714286  17.355372   10.588235      16.981132   8.695652
# media          8.928571  11.570248    2.352941       7.547170   7.246377
# mobilization   5.357143   2.479339    4.705882       0.000000   2.898551
# other          1.785714   0.826446    0.000000       1.886792   1.449275
# personal      16.071429  24.793388   18.823529      18.867925   8.695652
# policy        39.285714  23.140496   29.411765      26.415094  34.782609
# support       16.071429  19.008264   29.411765      24.528302  30.434783
#
# estado          Wyoming
# message
# attack         0.000000
# constituency   4.761905
# information    0.000000
# media          9.523810
# mobilization   0.000000
# other          0.000000
# personal      19.047619
# policy        61.904762
# support        4.761905
#
# [9 rows x 54 columns]

# %% [markdown]
# #### Idioma

# %%
español_mensaje = posts_español.groupby(['language_name', 'message']).agg(
    cantidad_de_posts =  ('unit_id', 'count'))
español_mensaje
# Out:
#                                   cantidad_de_posts
# language_name       message
# Spanish , Castilian attack                        1
#                     constituency                  1
#                     information                   4
#                     media                         6
#                     other                         4
#                     personal                      6
#                     policy                        8
#                     support                       7

# %%
idiomas_mensaje = political_posts.groupby(['language_name', 'message']).agg(
    cantidad_de_posts =  ('unit_id', 'count')).reset_index()
idiomas_mensaje
# Out:
#           language_name       message  cantidad_de_posts
# 0           Desconocido   information                  4
# 1           Desconocido         media                  1
# 2           Desconocido         other                  1
# 3           Desconocido      personal                  1
# 4           Desconocido        policy                  3
# 5           Desconocido       support                  1
# 6               English        attack                171
# 7               English  constituency                151
# 8               English   information                639
# 9               English         media                270
# 10              English  mobilization                129
# 11              English         other                116
# 12              English      personal               1163
# 13              English        policy               1400
# 14              English       support                913
# 15  Spanish , Castilian        attack                  1
# 16  Spanish , Castilian  constituency                  1
# 17  Spanish , Castilian   information                  4
# 18  Spanish , Castilian         media                  6
# 19  Spanish , Castilian         other                  4
# 20  Spanish , Castilian      personal                  6
# 21  Spanish , Castilian        policy                  8
# 22  Spanish , Castilian       support                  7

# %%
idiomas_mensaje.pivot_table( values='cantidad_de_posts', index=['message'],columns=['language_name']).apply(lambda x: x/x.sum() * 100)
# Out:
# language_name  Desconocido    English  Spanish , Castilian
# message
# attack                 NaN   3.453150             2.702703
# constituency           NaN   3.049273             2.702703
# information      36.363636  12.903877            10.810811
# media             9.090909   5.452342            16.216216
# mobilization           NaN   2.605008                  NaN
# other             9.090909   2.342488            10.810811
# personal          9.090909  23.485460            16.216216
# policy           27.272727  28.271405            21.621622
# support           9.090909  18.436995            18.918919
